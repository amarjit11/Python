# %% [markdown]
# #### Syntax refer to a set of rules that are designed to define a combination of symbols that should be correctly structured programs in a language, basically its correct arrangements of words, symbols in the code
# #### Symentics refers to meaning of interpretation of symbols, haracters and commands in language,it is about what the code is supposed to do when it runs

# %%
## baisc synatx of python andcase senstivity

name="python"
NAME="Cobra"
print(name)
print(NAME)
# Out:
# python
# Cobra

# %%
## indentation in python- consistent use of 4spaces or 1tab, to define the blocks of code
## other programs use curly braces to define the blocks of code, but in python we use indentation. to define the blocks of code and hierarchy of code. it is important to maintain the same level of indentation for all the lines of code in a block. otherwise, it will result in an error.

age=25
if age>=18:
	print("you are eligible to vote",(age))
# Out:
# you are eligible to vote 25

# %%
## line continuation in python- if a line of code is too long, we can use the backslash (\) to indicate that the line continues on the next line. this is useful for improving the readability of the code.
total=100+200+300+400+500+600+700+800+900+1000\
+1100+1200+1300+1400+1500
print(total)
# Out:
# 12000

# %%
## multiple statements on a single line- we can use a semicolon (;) to separate multiple statements on a single line. however, it is generally recommended to avoid using this feature as it can make the code less readable.
a=10; b=20; c=a+b; print(c)
# Out:
# 30

# %%
## understand semantics of python- semantics refers to the meaning of the code. it is important to understand the semantics of python in order to write correct and efficient code. for example, the following code will not produce the expected result because it does not follow the correct semantics of python.
x=10
age=24
name="Amarjit"
type(age),type(name)
# Out:
# (int, str)

# %%
# type inference in python- python is a dynamically typed language, which means that the type of a variable is determined at runtime. however, it is important to understand the type inference rules of python in order to write correct and efficient code. for example, the following code will produce the expected result because it follows the correct semantics of python.
x=10
print(type(x))
x="amarjit"
print(type(x))
# Out:
# <class 'int'>
# <class 'str'>

# %%
age=25
if age>=18:
	print("you are eligible to vote",(age))
# Out:
# you are eligible to vote 25

# %%
## name error- this error occurs when we try to use a variable that has not been defined. for example, the following code will produce a name error because the variable 'm' has not been defined.
k=m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 k=m
#
# NameError: name 'm' is not defined

# %%
## example identenation 
if True:
	print("this is true")
	if False:			
		print("this is false")
	print("this shoyld print")
else:
	print("this is outside the if block")
# Out:
# this is true
# this shoyld print
