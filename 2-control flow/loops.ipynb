# %% [markdown]
# #### Loop

# %%
range(0,5)
# Out:
# range(0, 5)

# %%
## for loop

for i in range(1,6):
	print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(11,1,-2):
	print(i)
# Out:
# 11
# 9
# 7
# 5
# 3
