# %% [markdown]
# #### Data Types

# %%
## DataType: Python
## Description: A simple Python script to demonstrate basic syntax and functionality.	
## Data type is a classification of data  that tells the compiler or interpreter how the programmer wants the data to be used, they decide the type of operation will be performed and the amount of memory to be allocated for the data.

# %%
## integer Example
age=25
type(age)
# Out:
# int

# %%
## float Example
pi=3.14
print(pi)
type(pi)
# Out:
# 3.14
# float

# %%
## string example
name="Amarjit Kumar"
print(name)
type(name)
# Out:
# Amarjit Kumar
# str

# %%
## boolean example
is_student=True
print(is_student)
type(is_student)
# Out:
# True
# bool
